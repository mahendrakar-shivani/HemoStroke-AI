# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !git clone https://github.com/mahendrakar-shivani/HemoStroke-AI.git
# %cd HemoStroke-AI
# Out:
# /content
# Cloning into 'HemoStroke-AI'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 109 (delta 36), reused 88 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (109/109), 2.31 MiB | 28.90 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /content/HemoStroke-AI

# %%
import zipfile, os

zip_path = '/content/drive/MyDrive/HemoStroke-AI/png_dataset_fixed.zip'
extract_path = '/content/HemoStroke-AI/data/processed'
os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Fixed dataset extracted!")
# Out:
# Fixed dataset extracted!

# %%
import os
normal = len(os.listdir('/content/HemoStroke-AI/data/processed/png/Normal'))
stroke = len(os.listdir('/content/HemoStroke-AI/data/processed/png/Stroke'))
print(f"Normal: {normal}, Stroke: {stroke}")
# Out:
# Normal: 4427, Stroke: 2223

# %%
# !pip install pydicom nibabel -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 41.3 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !git clone https://github.com/mahendrakar-shivani/HemoStroke-AI.git
# %cd HemoStroke-AI
# Out:
# /content
# Cloning into 'HemoStroke-AI'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 109 (delta 36), reused 88 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (109/109), 2.31 MiB | 7.05 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /content/HemoStroke-AI

# %%
import zipfile, os

zip_path = '/content/drive/MyDrive/HemoStroke-AI/png_dataset_fixed.zip'
extract_path = '/content/HemoStroke-AI/data/processed'
os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Fixed dataset extracted!")
# Out:
# Fixed dataset extracted!

# %%
import os
normal = len(os.listdir('/content/HemoStroke-AI/data/processed/png/Normal'))
stroke = len(os.listdir('/content/HemoStroke-AI/data/processed/png/Stroke'))
print(f"Normal: {normal}, Stroke: {stroke}")
# Out:
# Normal: 4427, Stroke: 2223

# %%
# !pip install pydicom nibabel -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 34.6 MB/s eta 0:00:00

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# True
# Tesla T4

# %%
import sys
sys.path.insert(0, '/content/HemoStroke-AI/src')

# %cd /content/HemoStroke-AI
# !python src/train.py
# Out:
# /content/HemoStroke-AI
# Device: cuda
#
# Dataset loaded:
#   Normal (0) : 4427
#   Stroke (1) : 2223
#   Total      : 6650
# Train: 5320 | Test: 1330
#
# ...
#   Training: CNN Basic
# ...
# Epoch [01/10] Loss: 0.9082 | Acc: 56.02% | Dice: 0.541 | IoU: 0.371 | Sens: 0.737 | Spec: 0.464 | F1: 0.541
#   ✓ Saved best model (56.02%) → outputs/models/cnn_basic.pth
# Epoch [02/10] Loss: 0.6427 | Acc: 52.71% | Dice: 0.572 | IoU: 0.401 | Sens: 0.900 | Spec: 0.325 | F1: 0.572
# Epoch [03/10] Loss: 0.5866 | Acc: 72.86% | Dice: 0.523 | IoU: 0.354 | Sens: 0.423 | Spec: 0.894 | F1: 0.523
#   ✓ Saved best model (72.86%) → outputs/models/cnn_basic.pth
# Epoch [04/10] Loss: 0.5310 | Acc: 77.29% | Dice: 0.628 | IoU: 0.458 | Sens: 0.545 | Spec: 0.897 | F1: 0.628
#   ✓ Saved best model (77.29%) → outputs/models/cnn_basic.pth
# Epoch [05/10] Loss: 0.4955 | Acc: 77.97% | Dice: 0.704 | IoU: 0.544 | Sens: 0.746 | Spec: 0.798 | F1: 0.704
#   ✓ Saved best model (77.97%) → outputs/models/cnn_basic.pth
# ...

# %%
import shutil, os

drive_dir = '/content/drive/MyDrive/HemoStroke-AI/outputs'
os.makedirs(f'{drive_dir}/models', exist_ok=True)
os.makedirs(f'{drive_dir}/plots', exist_ok=True)

for f in os.listdir('outputs/models'):
    shutil.copy2(f'outputs/models/{f}', f'{drive_dir}/models/{f}')
for f in os.listdir('outputs/plots'):
    shutil.copy2(f'outputs/plots/{f}', f'{drive_dir}/plots/{f}')

print("Backed up to Drive successfully!")
# Out:
# Backed up to Drive successfully!
