# %%
from google.colab import drive
drive.mount('/content/drive')
print("Drive mounted successfully!")
# Out:
# Mounted at /content/drive
# Drive mounted successfully!

# %%
# !git clone https://github.com/mahendrakar-shivani/HemoStroke-AI.git
# %cd HemoStroke-AI
# !ls
# Out:
# Cloning into 'HemoStroke-AI'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 81 (delta 23), reused 66 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (81/81), 1.12 MiB | 4.64 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# /content/HemoStroke-AI
# main.py  outputs  README.md  requirements.txt  src

# %%
import zipfile
import os

# Path to your uploaded zip in Drive
zip_path = '/content/drive/MyDrive/HemoStroke-AI/png_dataset.zip'

# Extract directly into your project's data folder
extract_path = '/content/HemoStroke-AI/data/processed'
os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
import os

normal_path = '/content/HemoStroke-AI/data/processed/png/Normal'
stroke_path = '/content/HemoStroke-AI/data/processed/png/Stroke'

normal_count = len(os.listdir(normal_path))
stroke_count = len(os.listdir(stroke_path))

print(f"Normal images: {normal_count}")
print(f"Stroke images: {stroke_count}")
print(f"Total: {normal_count + stroke_count}")
# Out:
# Normal images: 4427
# Stroke images: 2223
# Total: 6650

# %%
# !pip install pydicom nibabel -q
print("Libraries installed!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 28.7 MB/s eta 0:00:00
# Libraries installed!

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

if device.type == "cuda":
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
else:
    print("WARNING: No GPU detected. Go to Runtime > Change runtime type > GPU")
# Out:
# Using device: cuda
# GPU Name: Tesla T4

# %%
import sys
sys.path.insert(0, '/content/HemoStroke-AI/src')
print("Path added!")
# Out:
# Path added!

# %%
from dataset import load_dataset, get_transforms
from models import MODEL_REGISTRY
from metrics import compute_all_metrics

print("All modules imported successfully!")
print("Available models:", list(MODEL_REGISTRY.keys()))
# Out:
# All modules imported successfully!
# Available models: ['CNN Basic', 'CNN Deep', 'CNN Lightweight']

# %%
# %cd /content/HemoStroke-AI
# !python src/train.py
# Out:
# /content/HemoStroke-AI
# Device: cuda
#
# Dataset loaded:
#   Normal (0) : 4427
#   Stroke (1) : 2223
#   Total      : 6650
# Train: 5320 | Test: 1330
#
# ...
#   Training: CNN Basic
# ...
# Epoch [01/10] Loss: 0.8618 | Acc: 74.14% | Dice: 0.622 | IoU: 0.451 | Sens: 0.605 | Spec: 0.816 | F1: 0.622
#   ✓ Saved best model (74.14%) → outputs/models/cnn_basic.pth
# Epoch [02/10] Loss: 0.5404 | Acc: 74.44% | Dice: 0.706 | IoU: 0.545 | Sens: 0.872 | Spec: 0.675 | F1: 0.706
#   ✓ Saved best model (74.44%) → outputs/models/cnn_basic.pth
# Epoch [03/10] Loss: 0.5094 | Acc: 81.05% | Dice: 0.707 | IoU: 0.547 | Sens: 0.650 | Spec: 0.898 | F1: 0.707
#   ✓ Saved best model (81.05%) → outputs/models/cnn_basic.pth
# Epoch [04/10] Loss: 0.4610 | Acc: 80.08% | Dice: 0.738 | IoU: 0.585 | Sens: 0.799 | Spec: 0.802 | F1: 0.738
# Epoch [05/10] Loss: 0.4416 | Acc: 81.35% | Dice: 0.755 | IoU: 0.606 | Sens: 0.816 | Spec: 0.812 | F1: 0.755
#   ✓ Saved best model (81.35%) → outputs/models/cnn_basic.pth
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

plots_dir = '/content/HemoStroke-AI/outputs/plots'
plot_files = sorted([f for f in os.listdir(plots_dir) if f.endswith('.png')])

for plot_file in plot_files:
    img = mpimg.imread(os.path.join(plots_dir, plot_file))
    plt.figure(figsize=(14, 5))
    plt.imshow(img)
    plt.axis('off')
    plt.title(plot_file)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1245/3902546301.py in <cell line: 0>()
#       4
#       5 plots_dir = '/content/HemoStroke-AI/outputs/plots'
# ----> 6 plot_files = sorted([f for f in os.listdir(plots_dir) if f.endswith('.png')])
#       7
#       8 for plot_file in plot_files:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/HemoStroke-AI/outputs/plots'

# %%
import os
os.chdir('/content/HemoStroke-AI')
print(os.getcwd())
# !ls
# !ls outputs
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1245/2668724081.py in <cell line: 0>()
#       1 import os
# ----> 2 os.chdir('/content/HemoStroke-AI')
#       3 print(os.getcwd())
#       4 get_ipython().system('ls')
#       5 get_ipython().system('ls outputs')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/HemoStroke-AI'

# %%
# !ls /content/
# Out:
# sample_data

# %%
# %cd /content
# !git clone https://github.com/mahendrakar-shivani/HemoStroke-AI.git
# %cd HemoStroke-AI
# !ls
# Out:
# /content
# Cloning into 'HemoStroke-AI'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 81 (delta 23), reused 66 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (81/81), 1.12 MiB | 21.71 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# /content/HemoStroke-AI
# main.py  outputs  README.md  requirements.txt  src

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = '/content/drive/MyDrive/HemoStroke-AI/png_dataset.zip'
extract_path = '/content/HemoStroke-AI/data/processed'
os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extracted!")
# Out:
# Extracted!

# %%
import os
normal = len(os.listdir('/content/HemoStroke-AI/data/processed/png/Normal'))
stroke = len(os.listdir('/content/HemoStroke-AI/data/processed/png/Stroke'))
print(f"Normal: {normal}, Stroke: {stroke}")
# Out:
# Normal: 4427, Stroke: 2223

# %%
# !pip install pydicom nibabel -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 33.4 MB/s eta 0:00:00

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# True
# Tesla T4

# %%
import sys
sys.path.insert(0, '/content/HemoStroke-AI/src')

# %cd /content/HemoStroke-AI
# !python src/train.py
# Out:
# /content/HemoStroke-AI
# Device: cuda
#
# Dataset loaded:
#   Normal (0) : 4427
#   Stroke (1) : 2223
#   Total      : 6650
# Train: 5320 | Test: 1330
#
# ...
#   Training: CNN Basic
# ...
# Epoch [01/10] Loss: 0.8603 | Acc: 73.83% | Dice: 0.619 | IoU: 0.449 | Sens: 0.605 | Spec: 0.811 | F1: 0.619
#   ✓ Saved best model (73.83%) → outputs/models/cnn_basic.pth
# Epoch [02/10] Loss: 0.5438 | Acc: 76.69% | Dice: 0.710 | IoU: 0.551 | Sens: 0.812 | Spec: 0.743 | F1: 0.710
#   ✓ Saved best model (76.69%) → outputs/models/cnn_basic.pth
# Epoch [03/10] Loss: 0.5073 | Acc: 80.83% | Dice: 0.718 | IoU: 0.560 | Sens: 0.692 | Spec: 0.871 | F1: 0.718
#   ✓ Saved best model (80.83%) → outputs/models/cnn_basic.pth
# Epoch [04/10] Loss: 0.4523 | Acc: 80.75% | Dice: 0.744 | IoU: 0.592 | Sens: 0.795 | Spec: 0.814 | F1: 0.744
# Epoch [05/10] Loss: 0.4360 | Acc: 82.11% | Dice: 0.760 | IoU: 0.612 | Sens: 0.803 | Spec: 0.831 | F1: 0.760
#   ✓ Saved best model (82.11%) → outputs/models/cnn_basic.pth
# ...

# %%
import shutil, os

drive_dir = '/content/drive/MyDrive/HemoStroke-AI/outputs'
os.makedirs(f'{drive_dir}/models', exist_ok=True)
os.makedirs(f'{drive_dir}/plots', exist_ok=True)

for f in os.listdir('outputs/models'):
    shutil.copy2(f'outputs/models/{f}', f'{drive_dir}/models/{f}')
for f in os.listdir('outputs/plots'):
    shutil.copy2(f'outputs/plots/{f}', f'{drive_dir}/plots/{f}')

print("Backed up to Drive successfully!")
# Out:
# Backed up to Drive successfully!

# %%
import os

drive_dir = '/content/drive/MyDrive/HemoStroke-AI/outputs'
print("Models in Drive:")
print(os.listdir(f'{drive_dir}/models'))
print("\nPlots in Drive:")
print(os.listdir(f'{drive_dir}/plots'))
# Out:
# Models in Drive:
# ['cnn_deep.pth', 'cnn_lightweight.pth', 'cnn_basic.pth']
#
# Plots in Drive:
# ['cnn_basic_curves.png', 'model_comparison.png', 'cnn_deep_curves.png', 'before_after.png', 'cnn_lightweight_curves.png', 'preprocessing_steps.png']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

plots_dir = '/content/HemoStroke-AI/outputs/plots'
plot_files = sorted([f for f in os.listdir(plots_dir) if f.endswith('.png')])

for plot_file in plot_files:
    img = mpimg.imread(os.path.join(plots_dir, plot_file))
    plt.figure(figsize=(14, 5))
    plt.imshow(img)
    plt.axis('off')
    plt.title(plot_file)
    plt.show()
